# %% [markdown]
# ##Get started with Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load CSV

# %%
data= pd.read_csv("/data/dssg/stumptown/data/Building_Violations_sample_50000.csv")

# %%
data.head(3)
# Out:
#    Unnamed: 0       ID VIOLATION LAST MODIFIED DATE VIOLATION DATE  \
# 0           0  5063843                   05/21/2015     05/21/2015
# 1           1  5063990                   05/21/2015     05/21/2015
# 2           2  5064022                   05/21/2015     05/21/2015
#
#   VIOLATION CODE VIOLATION STATUS VIOLATION STATUS DATE  \
# 0       CN065014             OPEN                   NaN
# 1       CN044013             OPEN                   NaN
# 2       CN104035             OPEN                   NaN
#
#             VIOLATION DESCRIPTION             VIOLATION LOCATION  \
# 0                  REPAIR LINTELS                 OTHER   :    :
# 1  PIPE OPENING W/NONCOMBUST MATL  OTHER   :    :MULTIPLE FLOORS
# 2                 MAINTAIN WINDOW                 OTHER   :    :
#
#                         VIOLATION INSPECTOR COMMENTS  \
# 0                                   LINTELS; RUSTED.
# 1  OPENINGS AROUND PIPES, SEAL WITH APPROVED MATE...
# ...

# %%
data.tail(3)
# Out:
#        Unnamed: 0       ID VIOLATION LAST MODIFIED DATE VIOLATION DATE  \
# 49997       49997  1430847                   10/14/2008     01/01/2006
# 49998       49998  1734149                   09/16/2008     01/01/2006
# 49999       49999  1834762                   01/12/2007     01/01/2006
#
#       VIOLATION CODE VIOLATION STATUS VIOLATION STATUS DATE  \
# 49997       CN031013         COMPLIED            07/10/2008
# 49998       CN135016         COMPLIED            09/05/2008
# 49999       CN190019         COMPLIED            01/11/2007
#
#             VIOLATION DESCRIPTION VIOLATION LOCATION  \
# 49997  FIRE EXTNGSHR REQ, RESDNTL                NaN
# 49998                MICE/RODENTS                NaN
# 49999  ARRANGE PREMISE INSPECTION                NaN
#
#                             VIOLATION INSPECTOR COMMENTS  \
# 49997            ALL ELEVATION MISSING FIRE EXTINGUISHER
# 49998                                   MICE ON PREMISES
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                        int64
# ID                                int64
# VIOLATION LAST MODIFIED DATE     object
# VIOLATION DATE                   object
# VIOLATION CODE                   object
# VIOLATION STATUS                 object
# VIOLATION STATUS DATE            object
# VIOLATION DESCRIPTION            object
# VIOLATION LOCATION               object
# VIOLATION INSPECTOR COMMENTS     object
# VIOLATION ORDINANCE              object
# INSPECTOR ID                     object
# INSPECTION NUMBER                 int64
# INSPECTION STATUS                object
# INSPECTION WAIVED                object
# INSPECTION CATEGORY              object
# DEPARTMENT BUREAU                object
# ADDRESS                          object
# PROPERTY GROUP                    int64
# SSA                              object
# LATITUDE                        float64
# LONGITUDE                       float64
# LOCATION                         object
# dtype: object

# %%
import re

def space_to_snake(column_name):
    """Replace space with underscore """
    tmp = re.sub(r"\s+",'_',column_name)
    return tmp.lower()

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'ID', u'VIOLATION LAST MODIFIED DATE', u'VIOLATION DATE', u'VIOLATION CODE', u'VIOLATION STATUS', u'VIOLATION STATUS DATE', u'VIOLATION DESCRIPTION', u'VIOLATION LOCATION', u'VIOLATION INSPECTOR COMMENTS', u'VIOLATION ORDINANCE', u'INSPECTOR ID', u'INSPECTION NUMBER', u'INSPECTION STATUS', u'INSPECTION WAIVED', u'INSPECTION CATEGORY', u'DEPARTMENT BUREAU', u'ADDRESS', u'PROPERTY GROUP', u'SSA', u'LATITUDE', u'LONGITUDE', u'LOCATION'], dtype='object')

# %%
tmp = []
for col in data.columns:
    tmp.append(space_to_snake(col))
data.columns=tmp

# %%
data.columns
# Out:
# Index([u'unnamed:_0', u'id', u'violation_last_modified_date', u'violation_date', u'violation_code', u'violation_status', u'violation_status_date', u'violation_description', u'violation_location', u'violation_inspector_comments', u'violation_ordinance', u'inspector_id', u'inspection_number', u'inspection_status', u'inspection_waived', u'inspection_category', u'department_bureau', u'address', u'property_group', u'ssa', u'latitude', u'longitude', u'location'], dtype='object')

# %%
pd.value_counts(data.violation_inspector_comments.isnull())
# Out:
# False    44705
# True      5295
# dtype: int64

# %%
for col in data.columns:
    print col
    print pd.value_counts(data[col].isnull())
# Out:
# unnamed:_0
# False    50000
# dtype: int64
# id
# False    50000
# dtype: int64
# violation_last_modified_date
# False    50000
# dtype: int64
# violation_date
# False    50000
# dtype: int64
# violation_code
# False    50000
# dtype: int64
# violation_status
# False    50000
# dtype: int64
# violation_status_date
# True     36488
# False    13512
# dtype: int64
# violation_description
# False    49624
# True       376
# dtype: int64
# violation_location
# True     32484
# False    17516
# dtype: int64
# violation_inspector_comments
# False    44705
# True      5295
# dtype: int64
# violation_ordinance
# False    48462
# True      1538
# dtype: int64
# inspector_id
# False    50000
# dtype: int64
# inspection_number
# False    50000
# dtype: int64
# inspection_status
# False    50000
# dtype: int64
# inspection_waived
# False    50000
# dtype: int64
# inspection_category
# False    50000
# dtype: int64
# department_bureau
# False    50000
# dtype: int64
# address
# False    50000
# ...

# %%
data.violation_inspector_comments = data.violation_inspector_comments.fillna("No comment")

# %%
pd.value_counts(data.violation_inspector_comments.isnull())
# Out:
# False    50000
# dtype: int64

# %%
data.dtypes
# Out:
# unnamed:_0                        int64
# id                                int64
# violation_last_modified_date     object
# violation_date                   object
# violation_code                   object
# violation_status                 object
# violation_status_date            object
# violation_description            object
# violation_location               object
# violation_inspector_comments     object
# violation_ordinance              object
# inspector_id                     object
# inspection_number                 int64
# inspection_status                object
# inspection_waived                object
# inspection_category              object
# department_bureau                object
# address                          object
# property_group                    int64
# ssa                              object
# latitude                        float64
# longitude                       float64
# location                         object
# dtype: object

# %%
data.apply(pd.Series.interpolate)
# Out:
#        unnamed:_0       id violation_last_modified_date violation_date  \
# 0               0  5063843                   05/21/2015     05/21/2015
# 1               1  5063990                   05/21/2015     05/21/2015
# 2               2  5064022                   05/21/2015     05/21/2015
# 3               3  5064019                   05/21/2015     05/21/2015
# 4               4  5064139                   05/21/2015     05/21/2015
# 5               5  5064153                   05/21/2015     05/21/2015
# 6               6  5064141                   05/21/2015     05/21/2015
# 7               7  5064257                   05/21/2015     05/21/2015
# 8               8  5064728                   05/21/2015     05/21/2015
# 9               9  5064742                   05/21/2015     05/21/2015
# 10             10  5064812                   05/21/2015     05/21/2015
# 11             11  5064815                   05/21/2015     05/21/2015
# ...

# %%
for col in data.columns:
    print col
    print pd.value_counts(data[col].isnull())
# Out:
# unnamed:_0
# False    50000
# dtype: int64
# id
# False    50000
# dtype: int64
# violation_last_modified_date
# False    50000
# dtype: int64
# violation_date
# False    50000
# dtype: int64
# violation_code
# False    50000
# dtype: int64
# violation_status
# False    50000
# dtype: int64
# violation_status_date
# True     36488
# False    13512
# dtype: int64
# violation_description
# False    49624
# True       376
# dtype: int64
# violation_location
# True     32484
# False    17516
# dtype: int64
# violation_inspector_comments
# False    50000
# dtype: int64
# violation_ordinance
# False    48462
# True      1538
# dtype: int64
# inspector_id
# False    50000
# dtype: int64
# inspection_number
# False    50000
# dtype: int64
# inspection_status
# False    50000
# dtype: int64
# inspection_waived
# False    50000
# dtype: int64
# inspection_category
# False    50000
# dtype: int64
# department_bureau
# False    50000
# dtype: int64
# address
# False    50000
# dtype: int64
# ...
